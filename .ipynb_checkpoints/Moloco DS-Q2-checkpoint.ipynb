# %%
import pandas as pd
import numpy as np

#loading data
df = pd.read_csv('Q2_data.csv',header= None)
df.columns = ['A','B','C']

# %%
df
# Out:
#           A      B       C
# 0     0.490 -0.180   11.50
# 1    -1.410 -1.230   11.80
# 2     0.943  4.510   -3.24
# 3     3.570  5.070  -23.90
# 4    -1.700  6.910  -22.10
# ..      ...    ...     ...
# 295   6.920 -0.421   33.20
# 296  11.700 -1.290  108.00
# 297   9.920  3.690 -126.00
# 298  11.400  6.290 -315.00
# 299  10.900  2.570  -97.70
#
# [300 rows x 3 columns]

# %% [markdown]
# ## EDA & Data Cleaning
#
# Data Cleanning: determine if there is any missing value, standardize the data if necessary

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# No missing values. Let's check if there is any outliers

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams['figure.figsize'] = (10.0, 5.0)


plt.figure(figsize=(10,5))
plt.subplot(1, 3, 1)
plt.boxplot(df['A'])
plt.title('A',fontsize=20)
plt.subplot(1, 3, 2)
plt.boxplot(df['B'])
plt.title('B',fontsize=20)
plt.subplot(1, 3, 3)
plt.boxplot(df['C'])
plt.title('C',fontsize=20)
plt.show()

# %%
#Standardizing the Data
df['A']=(df['A']-np.mean(df['A']))/np.std(df['A'])
df['B']=(df['B']-np.mean(df['B']))/np.std(df['B'])

X=(df.iloc[:,:-1])
y=(df['C'])

# %%
#getting rid of the minimum C value
df_prepared = df[df['C'] != min(df['C'])]

#Checking the Correlations
corr_matrix=df_prepared.corr()
corr_matrix

#the correlation between A and C is low
#the correlation between B and C is over 0.5
# Out:
#           A         B         C
# A  1.000000 -0.187059  0.010536
# B -0.187059  1.000000 -0.618516
# C  0.010536 -0.618516  1.000000

# %% [markdown]
# ## Implementing Linear & Logistic Regression
# Based on the eda, the linear regression would not work well especially because of the variable A. Here, we will implement both linear and logistic regression to see if one performs better than the other. For simplicity, we are going to fit the data using normal equation for linear regression and for logistic regression, we are going to use gradient descent.

# %%
class MyLinearRegression:
    def __init__ (self):
        """
        Initializing the regressor
        """
        self.theta=np.zeros(2,float)[:,np.newaxis]; #parameter vector; random
    
    def fitUsingNormalEquation(self,X_train,y_train):
        """
        Training using the Closed Form Equation
        """
        X_b=np.c_[np.ones(len(X_train),1),X_train] #adding additional column
        theta_best=np.linalg.pinv(X_b.T.dot(X_b)).dot(X_b.T).dot(y_train)
        self.theta=theta_best
    
    def predict(self,X_test):
        """
        Predicting the label
        """
        X_test = np.c_[np.ones((len(X_test),1)), X_test]
        y_predict = np.dot(X_test,self.theta)
        
        return y_predict

# %%
log_hist=[]


def sigmoid(x):
    return (1/(1+np.exp(-x)))

def loglikelihood(beta,X_train,y_train):
    scores=np.dot(X_train,beta)
    log=np.sum(y_train*scores-np.log(1+np.exp(scores)))
    return log
    
class MyLogRegression:
    def __init__(self):
        self.beta=np.random.random(3) 
        self.delta=0.01#learning rate
        self.log=9999999 #log likelihood
        
    
    def gradientAscent(self,X_train,y_train,beta, delta):
        scores=np.dot(X_train,beta)
        pred=sigmoid(scores)
        #print("y_train:",y_train,"\npred:", pred)
        error=(y_train)-pred
        gradient=np.dot(np.transpose(X_train),error)
    
        beta+=delta*gradient
        return gradient,beta
            
        
    def fitGradientAscent(self, X_train, y_train,delta=0.01,e=4,iters=1000):
        X_train = np.c_[np.ones((len(X_train),1)), X_train] #adding intercept
        self.beta=np.random.random(X_train.shape[1]) #randomly initializing
        self.delta=delta
        self.log=999999

        i=0
        
        while np.linalg.norm(self.log)>e:
            
            gradient,beta = self.gradientAscent(X_train, y_train, self.beta, self.delta)
            #print("gradient:",gradient) #uncomment this in order to check part B
            self.log=loglikelihood(self.beta,X_train,y_train)
            log_hist.append(self.log)
            #print(np.linalg.norm(self.log))
            i+=1
            if(i>iters): # just so it doesn't keep running
                break;
          
        print(gradient)
        self.beta=beta
        #print(self.beta)
        
    def predict(self, X_test):
        X_test = np.c_[np.ones((len(X_test),1)), X_test] #adding intercept
        #print(X_test)
        tmp = np.dot(X_test,self.beta)
        #print(tmp)
        #print(sigmoid(tmp))
        y_predict=np.round(sigmoid(tmp))
        return y_predict

# %%
## Linear Regression
myGradientDescentModel = MyLinearRegression()
myGradientDescentModel.fitUsingNormalEquation(X.values,y.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-40f232076d6a> in <module>
#       1 ## Linear Regression
#       2 myGradientDescentModel = MyLinearRegression()
# ----> 3 myGradientDescentModel.fitUsingNormalEquation(X.values,y.values)
#
# <ipython-input-23-ce73f451c0c1> in fitUsingNormalEquation(self, X_train, y_train)
#      10         Training using the Closed Form Equation
#      11         """
# ---> 12         X_b=np.c_[np.ones(len(X_train),1),X_train] #adding additional column
#      13         theta_best=np.linalg.pinv(X_b.T.dot(X_b)).dot(X_b.T).dot(y_train)
#      14         self.theta=theta_best
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     212
#     213     """
# --> 214     a = empty(shape, dtype, order)
#     215     multiarray.copyto(a, 1, casting='unsafe')
#     216     return a
#
# ...

# %% [markdown]
# We will almost try implementing polynomial regression on variable A.

# %%
#Logistic Regression
myGradientDescentModel = MyLogRegression()
myGradientDescentModel.fitGradientAscent(X.values,y.values,delta=0.001,iters=5000)
# Out:
# /Users/siyeonkim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """
# /Users/siyeonkim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# [-12524.4756     -13387.71148336   1034.06467129]

# %%
# Out:
# array([[-0.32133136, -0.73258193],
#        [-0.65550021, -1.08332101],
#        [-0.24165848,  0.83405264],
#        [ 0.22037393,  1.02111348],
#        [-0.70650493,  1.63574197],
#        [-0.70650493, -0.29499317],
#        [ 0.25027324, -0.43194843],
#        [-0.17886991,  0.91756194],
#        [-0.83137855, -0.53616804],
#        [-0.29706015,  1.43531964],
#        [-0.82786099,  1.19147246],
#        [-0.82961977, -0.24154721],
#        [-0.45570242,  0.83405264],
#        [-1.59293177,  0.84741413],
#        [-1.49268112, -1.33050855],
#        [-0.88062449,  1.34178921],
#        [-1.11806025,  0.01232107],
#        [-0.41758958,  1.08458055],
#        [-1.06177918, -0.60564778],
#        [-1.32911426,  1.31840661],
#        [ 0.19047461, -0.37449403],
#        [-0.70298736, -1.6378228 ],
#        [-0.54768679,  1.34846996],
#        [-1.33439061, -1.37059302],
#        [-0.87007179, -0.60798605],
#        [-0.52482261,  1.49878671],
#        [-1.19017037,  1.50212708],
# ...
